# %%
from rdflib import Graph, Namespace

# Load the document (RDF or other format) to parse with rdflib
file_path = ["./flight/ATM", "./flight/equipment", "./flight/general", "./flight/NAS"]

# Create an RDFLib graph
combined_graph = Graph()

combined_graph.bind("atm", Namespace("https://data.nasa.gov/ontologies/atmonto/ATM#"))
combined_graph.bind("doc", Namespace("https://data.nasa.gov/ontologies/atmonto/documentation#"))
combined_graph.bind("eqp", Namespace("https://data.nasa.gov/ontologies/atmonto/equipment#"))
combined_graph.bind("gen", Namespace("https://data.nasa.gov/ontologies/atmonto/general#"))
combined_graph.bind("nas", Namespace("https://data.nasa.gov/ontologies/atmonto/NAS#"))
combined_graph.bind("owl", Namespace("http://www.w3.org/2002/07/owl#"))
combined_graph.bind("rdf", Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#"))
combined_graph.bind("xml", Namespace("http://www.w3.org/XML/1998/namespace"))
combined_graph.bind("xsd", Namespace("http://www.w3.org/2001/XMLSchema#"))
combined_graph.bind("data", Namespace("https://data.nasa.gov/ontologies/atmonto/data#"))
combined_graph.bind("rdfs", Namespace("http://www.w3.org/2000/01/rdf-schema#"))

for path in file_path:
    temp_graph = Graph()
    temp_graph.parse(path, format="xml")

    combined_graph += temp_graph

combined_graph.serialize("combined_ontologies.ttl", format="ttl")
# Out:
# <Graph identifier=N8127d22a28dc432597fb2a7b731e3eba (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib import Graph, Namespace

final_graph = Graph()

final_graph.bind("atm", Namespace("https://data.nasa.gov/ontologies/atmonto/ATM#"))
final_graph.bind("doc", Namespace("https://data.nasa.gov/ontologies/atmonto/documentation#"))
final_graph.bind("eqp", Namespace("https://data.nasa.gov/ontologies/atmonto/equipment#"))
final_graph.bind("gen", Namespace("https://data.nasa.gov/ontologies/atmonto/general#"))
final_graph.bind("nas", Namespace("https://data.nasa.gov/ontologies/atmonto/NAS#"))
final_graph.bind("owl", Namespace("http://www.w3.org/2002/07/owl#"))
final_graph.bind("rdf", Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#"))
final_graph.bind("xml", Namespace("http://www.w3.org/XML/1998/namespace"))
final_graph.bind("xsd", Namespace("http://www.w3.org/2001/XMLSchema#"))
final_graph.bind("data", Namespace("https://data.nasa.gov/ontologies/atmonto/data#"))
final_graph.bind("rdfs", Namespace("http://www.w3.org/2000/01/rdf-schema#"))

flightInst = Graph()
flightInst.parse("./flight/flightInstNew.ttl", format="ttl")

combined_graph = Graph()
combined_graph.parse("./combined_ontologies.ttl", format="ttl")
# Out:
# <Graph identifier=N43012c9a4dd84457b4bda70b7fa34741 (<class 'rdflib.graph.Graph'>)>

# %%
final_graph += flightInst
final_graph += combined_graph

# %%
final_graph.serialize("flightInstSubset.ttl", format="ttl")
# Out:
# <Graph identifier=Ne03deedb2ee047298484cb915fc464fd (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### Create dataset

# %%
import pandas as pd

file_path = "flight/dataset.xlsx"
df = pd.read_excel(file_path, usecols=lambda column: column in ['Questions', 'Type', 'Triples', 'Answer'])
df
# Out:
#                                             Questions  \
# 0     Which flight took off first, AAL1102 or ACA722?
# 1   Which flight had a longer duration based on ac...
# 2   Calculate the total number of engines for flig...
# 3   What is the ICAO code of the departure airport...
# 4   What is the difference between the time zones ...
# 5   Which flight had a shorter interval between it...
# 6   Can flights ASQ4423 and ASA14 carry more than ...
# 7   Did both flights AAL1170 and ASA14 have aircra...
# 8   What is the time difference between UTC and th...
# 9   Which aircraft, used in either flight, was new...
# 10  Analyze both flight paths and determine which ...
# 11  Which flight's arrival airport is geographical...
# 12  Did both flights AAL100 and CHQ2945 operate un...
# 13  Compare the ICAO codes of both departure airpo...
# 14  What is the aircraft model flewn in flight ASA14?
# 15  \nWas flight ASQ4423's arrival on schedule as ...
# ...

# %%
df.at[10, 'Questions']
# Out:
# "Analyze both flight paths and determine which flight's aircraft had to fly a more complex route based on the number of waypoints in the flight route string: CHQ2945 or AAL1144?"

# %%
triples = """<https://data.nasa.gov/ontologies/atmonto/ATM#CHQ2945-201407150047> a <https://data.nasa.gov/ontologies/atmonto/ATM#Flight> .
<https://data.nasa.gov/ontologies/atmonto/ATM#CHQ2945-201407150047> <https://data.nasa.gov/ontologies/atmonto/ATM#hasActualRoute> <https://data.nasa.gov/ontologies/atmonto/ATM#ActualRouteCHQ2945-201407150047> .
<https://data.nasa.gov/ontologies/atmonto/ATM#ActualRouteCHQ2945-201407150047> <https://data.nasa.gov/ontologies/atmonto/general#hasSequencedItem> 
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150053042977>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150053074110>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150054073369>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150055056700>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150056037367>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150057041561>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150057137003>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150059006967>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150100030361>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150102035883>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150102142597>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150104047409>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150105007518>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150106018478>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150107037456>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150108044555>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150108156979>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150110010603>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150111011153>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150112039617>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150113028103>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150114016637>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150115024717>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150116004038>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150117015143>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150118018020>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150119026528>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150120031600>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150120145884>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150122006000>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150123006132>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150124043611>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150125021496>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150126058165>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150127003515>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150128002383>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150129022021>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150130020963>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150131000017>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150132026139>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150133030633>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150133124889>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150135001117>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150136024446>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150137005555>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150138016855>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150139022250>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150140049408>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150140134428>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150142013525>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150143008399>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150144029537>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150145033983>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150145139397>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150147007671>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150148013516>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150149016581>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150150048087>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150152076023>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150152187903>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150153021455>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150154028260>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150156044005>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150157040513>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150157167680>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150158036379>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150158068328>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150159084801>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150200024303>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150201047778>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150202027293>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150203024723>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150204025536>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150205058589>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150206063227>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150207038363>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150208039317>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150209039077>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150210035879>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150211040959>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150212026866>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407
,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150230088747>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150231092642>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150231098273>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150232081244>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150232082292>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150233078671>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150233085445>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150234081589>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150234083369>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150235065769>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150235109610>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150236074330>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150236109316>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150237098221>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150237104215>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150238101015>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150238106772>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150239089563>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150239100826>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150240096754>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150240101258>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150241105281>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150241114044>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150242093712>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150243009503>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150243093199>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150244003352>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150244116808>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150245001215>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150245097603>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150245109143>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150246111707>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150246124092>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150247106457>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150247108111>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150248112599>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150248113473>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150249107294>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150251022199>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150252021014>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150253011323>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150254007610>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150255005605>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150256003423>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150256118946>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150258038067>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150259026851>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150300027098>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150301027776>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150302027465>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150303021441>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150304020536>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150305018883>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150306054528>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150307050634>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150308042246>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150309036586>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150310039721>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150311043232>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150312032704>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150313027959>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150314053801>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150315052943>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150316038331>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150316060063>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150317041116>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150317055922>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150318027949>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150318041911>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150319036248>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150319042535>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150320049715>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150320070531>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150321049298>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150321073220>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150322059300>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150322070677>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150323053142>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150323074848>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150324054744>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150324068701>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150325048108>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150325064385>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150326067962>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150326102217>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150327061835>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150327082964>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150328056625>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150328074886>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150329084868>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150329096492>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150330074136>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150330088644>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150331074497>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150331079972>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150332069469>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150332078455>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150333082368>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150333105436>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150334078255>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150334095406>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150335072383>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150335091932>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150336070589>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150336090582>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150337098549>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150337104521>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150338086262>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150339093070>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150341006151>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150342004033>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150343003216>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150343101118>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150344099926>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150345093289>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150346097065>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150348022743>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150348073735>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150349005716>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150349023169>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150350004258>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150350008632>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150351016618>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150351035452>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150352016700>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150352035729>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150353022899>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150353028962>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150354004781>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150354025867>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150355003530>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150355024745>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150356024612>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150356039523>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150357018573>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150357028747>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150358014125>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150358029192>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150359015373>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150359025908>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150400011184>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150400018849>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150401011976>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150401021426>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150402020437>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150402041610>,
    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150403046185>.
"""

# %%
triples
# Out:
# '<https://data.nasa.gov/ontologies/atmonto/ATM#CHQ2945-201407150047> a <https://data.nasa.gov/ontologies/atmonto/ATM#Flight> .\n<https://data.nasa.gov/ontologies/atmonto/ATM#CHQ2945-201407150047> <https://data.nasa.gov/ontologies/atmonto/ATM#hasActualRoute> <https://data.nasa.gov/ontologies/atmonto/ATM#ActualRouteCHQ2945-201407150047> .\n<https://data.nasa.gov/ontologies/atmonto/ATM#ActualRouteCHQ2945-201407150047> <https://data.nasa.gov/ontologies/atmonto/general#hasSequencedItem> \n    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150053042977>,\n    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150053074110>,\n    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150054073369>,\n    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150055056700>,\n    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150056037367>,\n    <https://data.nasa.gov/ontologies/atmonto/ATM#TrackPt201407150057041561>,\n    <https://data.nasa.gov/ontologi
# ...

# %%
df.at[10, 'Triples'] = triples

# %%
json_data = df.to_dict(orient='records')

# %%
import json

with open('flight_dataset.json', 'w') as json_file:
    json.dump(json_data, json_file, indent=4)
